# %%
import pandas as pd

# %%
train_csv = pd.read_csv('train.csv')
test_csv = pd.read_csv('test.csv')

# %%
combined_csv = pd.concat([train_csv, test_csv], ignore_index=True)
combined_csv
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001002   Male      No          0      Graduate            No
# 1    LP001003   Male     Yes          1      Graduate            No
# 2    LP001005   Male     Yes          0      Graduate           Yes
# 3    LP001006   Male     Yes          0  Not Graduate            No
# 4    LP001008   Male      No          0      Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 976  LP002971   Male     Yes         3+  Not Graduate           Yes
# 977  LP002975   Male     Yes          0      Graduate            No
# 978  LP002980   Male      No          0      Graduate            No
# 979  LP002986   Male     Yes          0      Graduate            No
# 980  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# ...

# %%
shuffled_csv = combined_csv.sample(frac=1, random_state=42).reset_index(drop=True)
shuffled_csv
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001999    Male     Yes          2      Graduate           NaN
# 1    LP002588    Male     Yes          0      Graduate            No
# 2    LP001493    Male     Yes          2  Not Graduate            No
# 3    LP002842    Male     Yes          1      Graduate            No
# 4    LP001228    Male      No          0  Not Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 976  LP001369    Male     Yes          2      Graduate            No
# 977  LP001888  Female      No          0      Graduate            No
# 978  LP002358    Male     Yes          2      Graduate           Yes
# 979  LP002393  Female     NaN        NaN      Graduate            No
# 980  LP001350    Male     Yes        NaN      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
shuffled_csv.to_csv('loan.csv', index=False)

# %%
print('Merged together train and test and named Loan.csv')
# Out:
# Merged together train and test and named Loan.csv
